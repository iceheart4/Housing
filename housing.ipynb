# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt



st.title('California Housing Data(1990)')
df = pd.read_csv('housing.csv')
# Out:
# 2024-11-06 14:41:38.275 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-06 14:41:38.677
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\86132\AppData\Roaming\Python\Python312\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2024-11-06 14:41:38.677 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df.median_house_value.describe()
ad= df.median_house_value

# %%
# Plotting the histogram
plt.figure(figsize=(10, 6))
plt.hist(df['median_house_value'], bins=30, edgecolor='k')
plt.title('Histogram of Median House Value')
plt.xlabel('Median House Value')
plt.ylabel('Frequency') 
plt.show()

# %%
df.ocean_proximity.unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
# Radio button for income level
income_level = st.radio(
    "Choose income level",
    ('Low (≤2.5)', 'Medium (> 2.5 & < 4.5)', 'High (> 4.5)')
)


# Filter by income level
if income_level == 'Low (≤2.5)':
    df = df[df.median_income <= 2.5]
elif income_level == 'Medium (> 2.5 & < 4.5)':
    df = df[(df.median_income > 2.5) & (df.median_income < 4.5)]
else:
    df = df[df.median_income > 4.5]
# Out:
# 2024-11-06 15:06:42.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-06 15:06:42.673 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-06 15:06:42.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-06 15:06:42.674 Session state does not function when running a script without `streamlit run`
# 2024-11-06 15:06:42.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2024-11-06 15:06:42.674 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
